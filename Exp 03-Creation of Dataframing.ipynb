# %%
#Aim:performing the operation fro creation of an data frame

# %%
#name:Mohammad Mudakkir
#Roll no:41
#section:3A

# %%
import pandas as pd

# %%
df=pd.DataFrame([[10,15,14,18],[13,14,15,16],[18,19,20,11]],
         columns=["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    15   14   18
# 1  13    14   15   16
# 2  18    19   20   11

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df2=pd.DataFrame([[5,6,7,8]],
                columns=["CD","DBMS","DSS","CAO"])

# %%
df3=df.append(df2,ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    15   14   18
# 1  13    14   15   16
# 2  18    19   20   11
# 3   5     6    7    8

# %%
df3=df.append(df2)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    15   14   18
# 1  13    14   15   16
# 2  18    19   20   11
# 0   5     6    7    8

# %% [markdown]
# # Adding Attribute (Columns)name DM

# %%
df3["DM"]=[12,15,17,19]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    15   14   18  12
# 1  13    14   15   16  15
# 2  18    19   20   11  17
# 0   5     6    7    8  19

# %% [markdown]
# # Deleting Record From DataFrame

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    15   14   18  12
# 2  18    19   20   11  17
# 0   5     6    7    8  19

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    15   14   18
# 1  13    14   15   16
# 2  18    19   20   11
# 0   5     6    7    8

# %%
#finding mean of DSS
print("Mean of DSS:",df5["DSS"].mean())
# Out:
# Mean of DSS: 14.0

# %%
#finding median of DSS
print("Median of DSS:",df5["DSS"].median())
# Out:
# Median of DSS: 14.5

# %%
#finding mode of DSS
print("Mode of DSS:",df5["DSS"].mode())
# Out:
# Mode of DSS: 0     7
# 1    14
# 2    15
# 3    20
# dtype: int64

# %%
#finding min of DSS
print("Min of DSS:",df5["DSS"].min())
# Out:
# Min of DSS: 7

# %%
#finding max of DSS
print("Max of DSS:",df5["DSS"].max())
# Out:
# Max of DSS: 20

# %%
Name=["Mudakkir","Rafey","Huzefa","Anas","Affan"]
Name
# Out:
# ['Mudakkir', 'Rafey', 'Huzefa', 'Anas', 'Affan']

# %%
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1    Mudakkir
# 2       Rafey
# 3      Huzefa
# 4        Anas
# 5       Affan
# dtype: object

# %%
#Conclusion:-In this experiment, we successfully learned how to create and manipulate DataFrames using the Pandas library in Python.
