# %%
#Experiment No:-6

# %%
# Aim: To visualize and interpret data using matplotlib in Jupiter notebook

# %%
#Name:Mohammad Mudakkir
#Roll No:41
#Section:A
#Subject:Data Science And Statistics

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x = np.arange(1,50,5)arr1

# %%
x
# Out:
# array([ 1,  6, 11, 16, 21, 26, 31, 36, 41, 46])

# %%
print(x)
# Out:
# [ 1  6 11 16 21 26 31 36 41 46]

# %%
y=2*x

# %%
y
# Out:
# array([ 2, 12, 22, 32, 42, 52, 62, 72, 82, 92])

# %% [markdown]
# # Line chart

# %%
plt.plot(x, y, marker='o', color='blue', label="y = 2x")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.show()

# %% [markdown]
# # Bar chart

# %%
plt.bar(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.show()

# %%
arr1 = np.random.randint(1, 101, size=10)
arr3

# %%
print(arr1)
# Out:
# [17 40 42 28 75 12 34 48 22 18]

# %%
arr2 = np.random.randint(1, 101, size=10)

# %%
print(arr2)
# Out:
# [44 42 37 27 85 11 15  2 54 95]

# %%
plt.bar(arr1, arr2, color = "red" )
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(arr1, arr2, color = "red" )
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")
plt.show()

# %%
arr3 = [84,  9, 39, 70, 67, 43, 90, 78, 68, 75]

# %%
 plt.hist(arr3, bins=30, color='skyblue', edgecolor='black')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")
plt.show()

# %%
b = [84,  9, 39, 70, 67, 43, 90, 78, 68, 75]

# %%
plt.boxplot(b)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Box Plot")
plt.show()
